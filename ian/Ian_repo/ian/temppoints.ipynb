# %%
import numpy as np

# ── parameters ────────────────────────────────────────────────────────────────
L_values_data = [10, 20, 30, 40, 60, 70, 80, 90, 100]   # lattice sizes to generate
T_min, T_max  = 1.0, 3.6               # temperature range
N_temps       = 40                     # number of temperature points
N_per_temps   = 2500                   # samples per temperature point
Ntherm        = 10000                  # Wolff steps to thermalize
Ndecorr       = 200                     # Wolff steps between recorded samples
exclusion     = 0.5                    # half-width of critical exclusion zone

# ──────────────────────────────────────────────────────────────────────────────

temperatures_data = np.linspace(T_min, T_max, N_temps)
print(f"Generating data for L={L_values_data}...")
print(f"Temperature points: {temperatures_data}")
# Out:
# Generating data for L=[10, 20, 30, 40, 60, 70, 80, 90, 100]...
# Temperature points: [1.         1.06666667 1.13333333 1.2        1.26666667 1.33333333
#  1.4        1.46666667 1.53333333 1.6        1.66666667 1.73333333
#  1.8        1.86666667 1.93333333 2.         2.06666667 2.13333333
#  2.2        2.26666667 2.33333333 2.4        2.46666667 2.53333333
#  2.6        2.66666667 2.73333333 2.8        2.86666667 2.93333333
#  3.         3.06666667 3.13333333 3.2        3.26666667 3.33333333
#  3.4        3.46666667 3.53333333 3.6       ]
